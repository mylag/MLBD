# %% [markdown]
# http://stackoverflow.com/questions/36245039/how-can-i-plot-a-spectrogram-of-a-signal-by-computing-the-power-spectrum-on-binn
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.spectrogram.html

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

fs = 10e3
N = 1e5
amp = 2 * np.sqrt(2)
noise_power = 0.01 * fs / 2
t = np.arange(N) / float(fs)
mod = 500*np.cos(2*np.pi*0.25*t)
carrier = amp * np.sin(2*np.pi*3e3*t + mod)
noise = np.random.normal(scale=np.sqrt(noise_power), size=t.shape)
noise *= np.exp(-t/5)
x = carrier + noise

plt.figure(figsize=(15,6))
plt.plot(t,x)
plt.title('x')
plt.grid()
plt.show()


f, t, Sxx = signal.spectrogram(x, fs)
plt.figure(figsize=(8,8))
plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

print max(x)
print min(x)
# Out:
# 23.5240556049
# -22.9594145022

# %%
from scikits.audiolab import wavread

#filename = "/Users/aperezur/Desktop/Becasse1/3h1.wav"

#data, sample_frequency,encoding = wavread(filename)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b9011f2e99d5> in <module>()
# ----> 1 from scikits.audiolab import wavread
#       2
#       3 #filename = "/Users/aperezur/Desktop/Becasse1/3h1.wav"
#       4
#       5 #data, sample_frequency,encoding = wavread(filename)
#
# ImportError: No module named audiolab

# %%
length = waveFile.getnframes()
for i in range(0,length):
    waveData = waveFile.readframes(1)
    data = struct.unpack("<h", waveData)
    print(int(data[0]))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-02bdddaf96c9> in <module>()
#       2 for i in range(0,length):
#       3     waveData = waveFile.readframes(1)
# ----> 4     data = struct.unpack("<h", waveData)
#       5     print(int(data[0]))
#
# error: unpack requires a string argument of length 2
